# %%
import pandas as pd
df = pd.read_csv('../day1-data-cleaning/cleaned_btc_data.csv')

df['timestamp'] = pd.to_datetime(df['timestamp'])
df.set_index('timestamp', inplace=True)

# resample biar ringan
df = df.resample('D').mean()

# %%
df['return'] = df['close'].pct_change()

# %%
df['ma7'] = df['close'].rolling(7).mean()
df['ma30'] = df['close'].rolling(30).mean()

# %%
df['lag1'] = df['close'].shift(1)
df['lag2'] = df['close'].shift(2)
df['lag3'] = df['close'].shift(3)

# %%
df['volatility'] = df['close'].rolling(7).std()

# %%
df.dropna(inplace=True)

# %%
df.head()
# Out:
#                 open      high       low     close    volume    return  \
# timestamp
# 2012-01-30  5.456833  5.456833  5.456833  5.456833  0.015542 -0.018527
# 2012-01-31  5.662076  5.662292  5.661708  5.662292  0.072721  0.037652
# 2012-02-01  5.441035  5.441035  5.441028  5.441028  0.009411 -0.039077
# 2012-02-02  6.038306  6.038646  6.038222  6.038569  0.085821  0.109821
# 2012-02-03  6.175542  6.175542  6.175354  6.175354  0.196793  0.022652
#
#                  ma7      ma30      lag1      lag2      lag3  volatility
# timestamp
# 2012-01-30  5.930302  6.251111  5.559840  5.276444  5.854410    0.528490
# 2012-01-31  5.810578  6.284998  5.456833  5.559840  5.276444    0.469457
# 2012-02-01  5.645846  6.300532  5.662292  5.456833  5.559840    0.330395
# 2012-02-02  5.612774  6.332301  5.441028  5.662292  5.456833    0.262004
# 2012-02-03  5.658623  6.365800  6.038569  5.441028  5.662292    0.330472

# %%
df.to_csv('featured_btc_data.csv.csv', index=True)
